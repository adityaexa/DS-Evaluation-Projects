# %% [markdown]
# # Problem Definition

# %% [markdown]
# In this project,we will use the machine learning models to Predict the mpg attribute from given dataset.

# %%
1. importing the data
2. cleaning and preparing the data
3. exploring and visualizing the data
4. adding new features
5. splitting dataset into train_set and test_set
6. selecting error metric: mean absolute error vs mean squared error
7. Using varous algorithms:

    a. LinearRegression
    b. Lasso
    c. KNeighborsRegressor
    d. AdaBoostRegressor
    e. DecisionTreeRegressor
8. Using GridSearchCV for best parameter
9. Using r2score for best value
10. Find the cross val score
# Out:
#   File "<ipython-input-138-a3cc940ed0dc>", line 1
#     1. importing the data
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Importing Pakages

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore,boxcox
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Uploding Dataset

# %%
ds=pd.read_csv('auto-mpg.csv',header=None,delim_whitespace=True)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Read Dataset

# %%
#get shape of dataset
ds.shape
# Out:
# (398, 9)

# %%
#get top 5 rows
ds.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
#get last 5 rows
ds.tail()
# Out:
#         0  1      2      3       4     5   6  7                8
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1  ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2        vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1    dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1      ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1       chevy s-10

# %%
#check the data type of dataset
ds.dtypes
# Out:
# 0    float64
# 1      int64
# 2    float64
# 3     object
# 4    float64
# 5    float64
# 6      int64
# 7      int64
# 8     object
# dtype: object

# %%
#get complete information about dataset
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# 0    398 non-null float64
# 1    398 non-null int64
# 2    398 non-null float64
# 3    398 non-null object
# 4    398 non-null float64
# 5    398 non-null float64
# 6    398 non-null int64
# 7    398 non-null int64
# 8    398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
#find the columns of dataset
ds.describe()
# Out:
#                 0           1           2            4           5  \
# count  398.000000  398.000000  398.000000   398.000000  398.000000
# mean    23.514573    5.454774  193.425879  2970.424623   15.568090
# std      7.815984    1.701004  104.269838   846.841774    2.757689
# min      9.000000    3.000000   68.000000  1613.000000    8.000000
# 25%     17.500000    4.000000  104.250000  2223.750000   13.825000
# 50%     23.000000    4.000000  148.500000  2803.500000   15.500000
# 75%     29.000000    8.000000  262.000000  3608.000000   17.175000
# max     46.600000    8.000000  455.000000  5140.000000   24.800000
#
#                 6           7
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
ds[ds[3]=='?']
# Out:
#         0  1      2  3       4     5   6  7                     8
# 32   25.0  4   98.0  ?  2046.0  19.0  71  1            ford pinto
# 126  21.0  6  200.0  ?  2875.0  17.0  74  1         ford maverick
# 330  40.9  4   85.0  ?  1835.0  17.3  80  2  renault lecar deluxe
# 336  23.6  4  140.0  ?  2905.0  14.3  80  1    ford mustang cobra
# 354  34.5  4  100.0  ?  2320.0  15.8  81  2           renault 18i
# 374  23.0  4  151.0  ?  3035.0  20.5  82  1        amc concord dl

# %% [markdown]
# Checking the dataframe whether question mark value is available

# %%
ds_new=ds[ds[3]!='?']

# %% [markdown]
# Filter and revoved the question mark dataset to get actual data

# %%
#get the shape of DF
ds_new.shape
# Out:
# (392, 9)

# %%
ds_new[3]=ds_new[3].astype(float)

# %% [markdown]
# changing column datatype

# %%
ds_new.dtypes
# Out:
# 0    float64
# 1      int64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6      int64
# 7      int64
# 8     object
# dtype: object

# %%
ds_new.rename(columns={0:'mpg',1:'cylinders',2:'displacement',3:'horsepower',4:'weight',5:'acceleration',6:'model year',7:'origin',8:'car name'},inplace=
             True)
ds_new
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# Rename the columns

# %%
#checking the carname
ds_new['car name'].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'plymouth satellite custom', 'ford torino 500', 'amc matador',
#        'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
#        'pontiac firebird', 'ford mustang', 'mercury capri 2000',
# ...

# %%
#Checking the unique model year
ds_new['model year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
ds_new.drop('car name',axis=1,inplace=True)

# %% [markdown]
# Droping the unnecessary column

# %%
#checking null value
ds_new.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin
# 0         False   False
# 1         False   False
# 2         False   False
# 3         False   False
# ...

# %%
#checking null count column wise
ds_new.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
#visualize the null value in heatmap
plt.figure(figsize=(12,12))
sns.heatmap(ds_new.isnull())

# %%
ds_new.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E313EB28C8>,
# ...
#       dtype=object)

# %% [markdown]
# Using hist plot to visualize each columns distribution

# %%
sns.pairplot(ds_new)

# %% [markdown]
# Checking distribution of column and relationship between others

# %% [markdown]
# # Handling data outliers,Correlation columns and skewness

# %%
for i in ds_new.columns:
    plt.boxplot(ds_new[i])
    print(i)
    print('\n')
    plt.show()
# Out:
# mpg
# cylinders
# displacement
# horsepower
# weight
# acceleration
# model year
# origin

# %% [markdown]
# After using boxplot, same outliers have been found in columns.

# %%
for i in ds_new.columns:
    print(i)
    sns.distplot(ds_new[i],bins=10)
    print('\n')
    plt.show()
# Out:
# mpg
# cylinders
# displacement
# horsepower
# weight
# acceleration
# model year
# origin

# %% [markdown]
# Checking the distribution of columns data, we found there is uneven skewness of diffrent columns like:
#
# according to the graph we have found the data are alleviating and deteriorating.

# %% [markdown]
# Removing Outliers

# %%
z=np.abs(zscore(ds_new))
print(z.shape)
ds_new=ds_new.loc[(abs(z)<3).all(axis=1)]
print(ds_new.shape)
# Out:
# (392, 8)
# (385, 8)

# %% [markdown]
# After removal of outliers we got actul 385 rows.

# %% [markdown]
# Around 7 outliers data has been deleted

# %% [markdown]
# Correlation:

# %%
ds_new.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.774643     -0.807068   -0.787812 -0.833590
# cylinders    -0.774643   1.000000      0.954300    0.849691  0.898992
# displacement -0.807068   0.954300      1.000000    0.890674  0.939709
# horsepower   -0.787812   0.849691      0.890674    1.000000  0.878480
# weight       -0.833590   0.898992      0.939709    0.878480  1.000000
# acceleration  0.395288  -0.486261     -0.517863   -0.669937 -0.402898
# model year    0.568161  -0.325974     -0.343222   -0.389594 -0.293136
# origin        0.562748  -0.564313     -0.617161   -0.456519 -0.583706
#
#               acceleration  model year    origin
# mpg               0.395288    0.568161  0.562748
# cylinders        -0.486261   -0.325974 -0.564313
# displacement     -0.517863   -0.343222 -0.617161
# horsepower       -0.669937   -0.389594 -0.456519
# weight           -0.402898   -0.293136 -0.583706
# ...

# %%
#Checking correlation in heatmap 
sns.heatmap(ds_new.corr(),annot=True)

# %% [markdown]
# Using heatmap to check correlated columns. We have found some of the columns are highly correlated(like origin,displacement,weight).

# %%
ds_new['horsepower']=boxcox(ds_new['horsepower'])[0]
ds_new['origin']=boxcox(ds_new['origin'])[0]
ds_new.skew()
# Out:
# mpg             0.432109
# cylinders       0.533598
# displacement    0.672639
# horsepower      0.023087
# weight          0.531125
# acceleration    0.227886
# model year      0.012683
# origin          0.553151
# dtype: float64

# %% [markdown]
# Handling skewness of data by using boxcox method

# %%
x=ds_new.drop(['mpg'],axis=1)
print(x.shape)
y=ds_new['mpg']
print(y.shape)
# Out:
# (385, 7)
# (385,)

# %% [markdown]
# separate input and output data

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.50972639,  1.13924694,  0.89660042, ..., -1.36045779,
#         -1.6478999 , -0.77192231],
#        [ 1.50972639,  1.56362076,  1.51550057, ..., -1.55115765,
#         -1.6478999 , -0.77192231],
#        [ 1.50972639,  1.24780769,  1.27514216, ..., -1.74185752,
#         -1.6478999 , -0.77192231],
#        ...,
#        [-0.85546043, -0.55824831, -0.40223261, ..., -1.51301768,
#          1.6379428 , -0.77192231],
#        [-0.85546043, -0.70628568, -0.6036257 , ...,  1.15678042,
#          1.6379428 , -0.77192231],
#        [-0.85546043, -0.71615484, -0.48072375, ...,  1.46190021,
#          1.6379428 , -0.77192231]])

# %% [markdown]
# Scaled input data for model

# %%
def maxr2_score(rg,x,y):
    max_r_score =0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        rg.fit(x_train,y_train)
        pred=rg.predict(x_test)
        r2_scr=r2_score(y_test,pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print('max r2 score corrasponding to ',final_r_state,'is',max_r_score)
    return final_r_state

# %% [markdown]
# Created function for finding the max r2 score value of model

# %% [markdown]
# # Applying different algorithms to create "mpg" Regression model

# %%
lg=LinearRegression()
r_state=maxr2_score(lg,x,y)
print('Mean r2 score for linear Regression:',cross_val_score(lg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for linear Regression',cross_val_score(lg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  79 is 0.8893253052284273
# Mean r2 score for linear Regression: 0.6370646233786973
# stander deviation in r2 score for linear Regression 0.18325151286294944

# %%
neighbors={'n_neighbors':range(1,20)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 6}

# %%
knr=KNeighborsRegressor(n_neighbors=6)
r_state=maxr2_score(knr,x,y)
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('stander deviation r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  96 is 0.9192738493416103
# Mean r2 score for KNN Regression: 0.701784830331876
# stander deviation r2 score for KNN Regression: 0.20629495830351116

# %%
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
print('Mean r2 score for Lasso Regration',cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for Lasso Regretion',cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  79 is 0.8892975732941826
# Mean r2 score for Lasso Regration 0.6367557468862292
# stander deviation in r2 score for Lasso Regretion 0.18377306772968025

# %%
ada_reg =AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.01,
#  'n_estimators': 1000}

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=0.01,n_estimators=500)
r_state=maxr2_score(ada_reg,x,y)
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  82 is 0.9266696698233939
# Mean r2 score for ada Boosting Regration: 0.7504724334802205
# Mean r2 score for ada Boosting Regration: 0.20282543191350913

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=51,test_size=0.20)
ada_reg.fit(x_train,y_train)
y_pred=ada_reg.predict(x_test)
print('RMSE is: ',np.sqrt(mean_squared_error(y_test,y_pred)))
print('MAE is: ',mean_absolute_error(y_test,y_pred))
print('r2_score is:',r2_score(y_test,y_pred))
print('cross val score Mean:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('cross val score STD:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
print('\n')
print(y_pred)
print(y_test)
# Out:
# RMSE is:  1.9233358467050883
# MAE is:  1.4753246753246751
# r2_score is: 0.9305413634384898
# cross val score Mean: 0.7479406935134528
# cross val score STD: 0.1942755386900636
#
#
# [28.1 15.5 24.  34.3 13.  23.  32.2 15.  29.  25.4 37.  20.2 18.  30.
#  15.  21.1 13.  34.5 14.  27.  22.  20.8 21.  28.  24.  14.5 15.  15.
#  34.5 27.5 18.  18.  18.  29.  14.5 14.  29.  23.  16.  12.  30.  26.
#  16.  13.  36.  28.1 34.1 34.5 14.  25.1 26.  25.4 32.  23.5 26.4 32.
#  18.1 19.  16.  30.  24.  34.2 25.5 14.  18.5 30.5 26.  19.  13.  19.
#  34.4 19.  15.5 19.2 14.  13.  20.6]
# 328    30.0
# 265    17.5
# 242    21.5
# 353    33.0
# 103    11.0
#        ...
# 213    13.0
# 300    23.9
# 139    14.0
# 106    12.0
# 280    21.5
# Name: mpg, Length: 77, dtype: float64

# %% [markdown]
# Ada boosting regration model is slightly better than other models because it has less mean absolute error and mean squared error.

# %%
plt.scatter(y_pred,y_test, alpha=0.5)
plt.show()

# %% [markdown]
# Visualized the test and predict data in scatter plot

# %%
joblib.dump(ada_reg,'auto-mpg_ada_reg.obj')
# Out:
# ['auto-mpg_ada_reg.obj']

# %% [markdown]
# Saving the model (Model name -auto-"mpg_ada_reg.obj")

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Depending upon the given features that were used as the inputs to the machine learning to predict the mpg attribute from given dataset. We imported data from auto-mpg.csv file, cleaned it, explored it to visualize, engineered some features to check skewness and correlation. Then, created function to search best r2 score also used GridSearchCV to find best parameter. Later applied diffrent algorithms with cross val score(LogisticRegression, SVC, KNeighborsClassifier, AdaBoostClassifier, GradientBoostingClassifier) to create best performing model and we found the AdaBoostRegressor performing slightly better than others.
