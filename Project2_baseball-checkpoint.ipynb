# %% [markdown]
# # Problem Definition

# %% [markdown]
# In this project,we will use the machine learning models to predict the number of wins a baseball team by using the provided dataset.

# %% [markdown]
# 1. importing the data
# 2. cleaning and preparing the data
# 3. exploring and visualizing the data
# 4. adding new features
# 5. splitting dataset into train_set and test_set
# 6. selecting error metric: mean absolute error vs mean squared error
# 7. Using varous algorithms:
#
#     a. LinearRegression
#     b. Lasso
#     c. KNeighborsRegressor
#     d. AdaBoostRegressor
#     e. DecisionTreeRegressor
# 8. Using GridSearchCV for best parameter
# 9. Using r2score for best value
# 10. Find the cross val score

# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # Uploding Dataset

# %%
#importing dataset by useing pandas.read_csv
ds=pd.read_csv('baseball.csv')
ds
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Read Dataset

# %%
#Find out the number of rows and columns
ds.shape
# Out:
# (30, 17)

# %%
#find the first five rows
ds.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#find the last five rows
ds.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#get columns data types
ds.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#get the columns
ds.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#get the complete details of columns data
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
# W      30 non-null int64
# R      30 non-null int64
# AB     30 non-null int64
# H      30 non-null int64
# 2B     30 non-null int64
# 3B     30 non-null int64
# HR     30 non-null int64
# BB     30 non-null int64
# SO     30 non-null int64
# SB     30 non-null int64
# RA     30 non-null int64
# ER     30 non-null int64
# ERA    30 non-null float64
# CG     30 non-null int64
# SHO    30 non-null int64
# SV     30 non-null int64
# E      30 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Describe dataset
ds.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#checking null value
ds.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
#set summary of null value
ds.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#find the null value in heatmap
sns.heatmap(ds.isnull())

# %% [markdown]
# # Handling data outliers and skewness

# %%
#checking outliers in boxplot
for i in ds.columns:
    plt.boxplot(x=ds[i])
    print(i)
    print('\n')
    plt.show()
# Out:
# W
# R
# AB
# H
# 2B
# 3B
# HR
# BB
# SO
# SB
# RA
# ER
# ERA
# CG
# SHO
# SV
# E

# %% [markdown]
# After using boxplot, many outliers have been found in columns.

# %%
#skewness subject wise
for i in ds.columns:
    if i != 'gender':
        sns.distplot(ds[i])
        plt.show()

# %% [markdown]
# Checking the distribution of columns data, we found the data skewed is positive

# %% [raw]
# checking correlated columns

# %%
#co-relation of data
ds.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#plot co-relation in heatmap
plt.figure(figsize=(12,12))
sns.heatmap(ds.corr(),annot=True)
plt.show()

# %% [markdown]
# Checking correlation in heatmap and we found there are some columns is highly correlated(AB,E,RA)

# %%
#hist plot of dataset
ds.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018DE68FA148>,
# ...
#       dtype=object)

# %% [markdown]
# Using hist plot to visualize each columns distribution

# %%
#pair plot of ds dataset
sns.pairplot(ds)

# %% [markdown]
# Checking distribution of column and relationship between others

# %%
#check the skewness of data
ds.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
z=np.abs(zscore(ds))
print(z.shape)
ds_new=ds.loc[(abs(z)<3).all(axis=1)]
print(ds_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# removed outliers by useing zscore and cheking the shape of table

# %%
#checking skewness of data
ds_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
plt.figure(figsize=(12,12))
sns.heatmap(ds_new.corr(),annot=True)

# %%
ds_new['H']=np.sqrt(ds_new['H'])
ds_new['CG']=np.sqrt(ds_new['CG'])
ds_new['SV']=np.sqrt(ds_new['SV'])
ds_new['E']=np.sqrt(ds_new['E'])

# %% [markdown]
# Handling skewness of data by using square root method

# %%
ds_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.761274
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.260678
# SHO    0.526943
# SV     0.370280
# E      0.714966
# dtype: float64

# %%
x=ds_new.drop(['E','AB','RA','ER','W'],axis=1)
print(x.shape)
y=ds_new['W']
print(y.shape)
# Out:
# (29, 12)
# (29,)

# %% [markdown]
# separate input and output data

# %%
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# Scaleing input data

# %%
def maxr2_score(rg,x,y):
    max_r_score =0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        rg.fit(x_train,y_train)
        pred=rg.predict(x_test)
        r2_scr=r2_score(y_test,pred)
       # print('r2 score corrasponding to',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print('max r2 score corrasponding to ',final_r_state,'is',max_r_score)
    return final_r_state

# %% [markdown]
# Created function for finding the max r2 score value of model

# %% [markdown]
# # Applying different algorithms to create model

# %%
lg=LinearRegression()
r_state=maxr2_score(lg,x,y)
print('Mean r2 score for linear Regression:',cross_val_score(lg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for linear Regression',cross_val_score(lg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  47 is 0.9933638896518766
# Mean r2 score for linear Regression: 0.348365929589021
# stander deviation in r2 score for linear Regression 0.6206311144311825

# %%
neighbors={'n_neighbors':range(1,20)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 6}

# %%
knr=KNeighborsRegressor(n_neighbors=6)
r_state=maxr2_score(knr,x,y)
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('stander deviation r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  44 is 0.7493518518518518
# Mean r2 score for KNN Regression: -0.0289729628356149
# stander deviation r2 score for KNN Regression: 0.8569849730328915

# %%
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
print('Mean r2 score for Lasso Regression',cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for Lasso Regression',cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  47 is 0.9933581573456538
# Mean r2 score for Lasso Regression 0.34933865479216253
# stander deviation in r2 score for Lasso Regression 0.6225490432857381

# %%
ada_reg =AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#        normalize=False, positive=False, precompute=False, random_state=None,
#        selection='cyclic', tol=0.0001, warm_start=False),
#  'learning_rate': 1,
#  'n_estimators': 100}

# %%
ada_reg=AdaBoostRegressor(base_estimator=lsreg,learning_rate=1,n_estimators=100)
r_state=maxr2_score(ada_reg,x,y)
print('Mean r2 score for ada Boosting Regression:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('Mean r2 score for ada Boosting Regression:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  47 is 0.9296663451666357
# Mean r2 score for ada Boosting Regression: 0.38071049712278426
# Mean r2 score for ada Boosting Regression: 0.8388403381750417

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=47,test_size=0.20)
lg.fit(x_train,y_train)
y_pred=lg.predict(x_test)
print('RMSE is: ',np.sqrt(mean_squared_error(y_test,y_pred)))
print('MAE is: ',mean_absolute_error(y_test,y_pred))
print('r2_score is:',r2_score(y_test,y_pred))
print('cross val score Mean:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('cross val score STD:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
print('\n')
print(y_pred)
print(y_test)
# Out:
# RMSE is:  0.9152183319033848
# MAE is:  0.8224423321042925
# r2_score is: 0.9933638896518766
# cross val score Mean: 0.3905837806897627
# cross val score STD: 0.6313750977144607
#
#
# [98.61987844 75.43521689 74.49230199 85.12512684 77.3001093  63.67753513]
# 15    100
# 3      76
# 28     74
# 11     86
# 13     76
# 19     64
# Name: W, dtype: int64

# %% [markdown]
# linear regression model is slightly better than other models because it has less mean absolute error.

# %%
plt.scatter(y_pred,y_test, alpha=0.5)
plt.show()

# %%
joblib.dump(lg,'baseball_lg.obj')
# Out:
# ['baseball_lg.obj']

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Depending upon the different features that were used as the inputs to the machine learning to predict the number of wins a baseball team.  We have used the EDA process to find out the correlated columns and data processing. And later we have used the different algorithms like linear regression, KNeighborsRegressor, LASSO & AdaBoostRegressor. Further, we have used the GridSearchCV parameter to get the best result for the algorithm.

# %% [markdown]
# After using all the above approaches we have concluded that LASSO provides the highest level of accuracy for machine learning i.e., approx... 99% regarding the baseball league for the year 2014.
