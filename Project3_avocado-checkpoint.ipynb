# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
ds= pd.read_csv('avocado.csv')
ds.rename(columns={'Unnamed: 0':'ID'},inplace=True)
ds.head()
# Out:
#    ID        Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0   0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1   1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2   2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3   3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4   4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
ds.tail()
# Out:
#        ID        Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244   7  2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245   8  2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246   9  2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247  10  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  11  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# ...

# %%
ds.dtypes
# Out:
# ID                int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
# ID              18249 non-null int64
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
ds.describe()
# Out:
#                  ID  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
ds.isnull()
# Out:
#           ID   Date  AveragePrice  Total Volume   4046   4225   4770  \
# 0      False  False         False         False  False  False  False
# 1      False  False         False         False  False  False  False
# 2      False  False         False         False  False  False  False
# 3      False  False         False         False  False  False  False
# 4      False  False         False         False  False  False  False
# ...      ...    ...           ...           ...    ...    ...    ...
# 18244  False  False         False         False  False  False  False
# 18245  False  False         False         False  False  False  False
# 18246  False  False         False         False  False  False  False
# 18247  False  False         False         False  False  False  False
# 18248  False  False         False         False  False  False  False
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags   type   year  region
# ...

# %%
ds.isnull().sum()
# Out:
# ID              0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(ds.isnull())

# %%
plt.figure(figsize=(16,16))
sns.countplot(y='region',data=ds)
plt.show()

# %%
sns.countplot(x='type',data=ds)

# %%
ds['Date']=pd.to_datetime(ds['Date'])
ds['Month']=ds['Date'].apply(lambda x:x.month)
ds['Day']=ds['Date'].apply(lambda x:x.day)
ds.head()
# Out:
#    ID       Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0   0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1   1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2   2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3   3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4   4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# ...

# %%
#droping year columns
ds.drop(['Date'],axis=1,inplace=True)
ds.head()
# Out:
#    ID  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0   0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1   1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2   2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3   3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4   4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
ds_1=ds.iloc[:,10:13:2]

# %%
ds_1.head()
# Out:
#            type  region
# 0  conventional  Albany
# 1  conventional  Albany
# 2  conventional  Albany
# 3  conventional  Albany
# 4  conventional  Albany

# %%
le=LabelEncoder()
for i in ds_1.columns:
    ds_1[i]=le.fit_transform(ds_1[i])

# %%
ds_1.tail()
# Out:
#        type  region
# 18244     1      53
# 18245     1      53
# 18246     1      53
# 18247     1      53
# 18248     1      53

# %%
ds.drop(['type','region'],axis=1,inplace=True)

# %%
ds
# Out:
#        ID  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0       0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1       1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2       2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3       3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4       4          1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...    ..           ...           ...      ...        ...     ...         ...
# 18244   7          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245   8          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246   9          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247  10          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248  11          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
# ...

# %%
ds_new= pd.concat((ds,ds_1),axis=1)

# %%
ds_new
# Out:
#        ID  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0       0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1       1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2       2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3       3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4       4          1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...    ..           ...           ...      ...        ...     ...         ...
# 18244   7          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245   8          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246   9          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247  10          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248  11          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
# ...

# %%
ds_new.corr()
# Out:
#                     ID  AveragePrice  Total Volume      4046      4225  \
# ID            1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume  0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046          0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225          0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770          0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags   -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags    0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags   -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags  -0.011546     -0.117592      0.747157  0.699377  0.688809
# year         -0.171667      0.093197      0.017193  0.003353 -0.009559
# Month        -0.777730      0.162409     -0.024689 -0.025803 -0.022108
# ...

# %%
plt.figure(figsize=(16,16))
sns.heatmap(ds_new.corr(),annot=True)
plt.show()

# %%
ds_new.skew()
# Out:
# ID               0.108334
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# Month            0.106617
# Day              0.014310
# type             0.000329
# region           0.000030
# dtype: float64

# %%
ds_new.drop(['ID'],axis=1,inplace=True)

# %%
plt.figure(figsize=(16,16))
sns.heatmap(ds_new.corr(),annot=True)
plt.show()

# %%
for i in ds_new.columns:
    plt.boxplot(ds_new[i])
    print(i)
    print('\n')
    plt.show()
# Out:
# AveragePrice
# Total Volume
# 4046
# 4225
# 4770
# Total Bags
# Small Bags
# Large Bags
# XLarge Bags
# year
# Month
# Day
# type
# region

# %%
for i in ds_new.columns:
    print(i)
    sns.distplot(ds_new[i],bins=10)
    print('\n')
    plt.show()
# Out:
# AveragePrice
# Total Volume
# 4046
# 4225
# 4770
# Total Bags
# Small Bags
# Large Bags
# XLarge Bags
# year
# Month
# Day
# type
# region

# %%
ds_new.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000236DD1090C8>,
# ...
#       dtype=object)

# %%
sns.pairplot(ds_new)

# %%
ds_new.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# Month            0.106617
# Day              0.014310
# type             0.000329
# region           0.000030
# dtype: float64

# %%
z=np.abs(zscore(ds_new))
print(z.shape)
ds_new=ds_new.loc[(abs(z)<3).all(axis=1)]
print(ds_new.shape)
# Out:
# (18249, 14)
# (17651, 14)

# %%
ds_new.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# year            0.229976
# Month           0.107408
# Day             0.011778
# type           -0.037741
# region          0.012798
# dtype: float64

# %%
ds_new['Total Volume']=np.log1p(ds_new['Total Volume'])
ds_new['4046']=np.log1p(ds_new['4046'])
ds_new['4225']=np.log1p(ds_new['4225'])
ds_new['4770']=np.log1p(ds_new['4770'])
ds_new['Total Bags']=np.log1p(ds_new['Total Bags'])
ds_new['Small Bags']=np.log1p(ds_new['Small Bags'])
ds_new['Large Bags']=np.log1p(ds_new['Large Bags'])
ds_new['XLarge Bags']=np.log1p(ds_new['XLarge Bags'])
ds_new.skew()
# Out:
# AveragePrice    0.377432
# Total Volume   -0.049950
# 4046           -0.420273
# 4225           -0.604619
# 4770            0.068532
# Total Bags     -0.384493
# Small Bags     -0.788988
# Large Bags     -0.610874
# XLarge Bags     1.216238
# year            0.229976
# Month           0.107408
# Day             0.011778
# type           -0.037741
# region          0.012798
# dtype: float64

# %%
plt.figure(figsize=(16,16))
sns.heatmap(ds_new.corr(),annot=True)
plt.show()

# %% [markdown]
# # Regression

# %%
x=ds_new.drop(['AveragePrice','region'],axis=1)
print(x.shape)
y=ds_new['AveragePrice']
print(y.shape)
# Out:
# (17651, 12)
# (17651,)

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# array([[-0.06196232, -0.58731803,  0.43156498, ...,  1.64461178,
#          1.28930873, -1.01904715],
#        [-0.13430157, -0.71946434,  0.35960138, ...,  1.64461178,
#          0.49165249, -1.01904715],
#        [ 0.21823548, -0.66899685,  0.68331601, ...,  1.64461178,
#         -0.30600376, -1.01904715],
#        ...,
#        [-0.76950251, -0.54445811, -0.69071773, ..., -1.46287832,
#          0.60560338,  0.98130886],
#        [-0.69459605, -0.46819541, -0.62012644, ..., -1.46287832,
#         -0.19205286,  0.98130886],
# ...

# %%
def maxr2_score(rg,x,y):
    max_r_score =0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        rg.fit(x_train,y_train)
        pred=rg.predict(x_test)
        r2_scr=r2_score(y_test,pred)
       # print('r2 score corrasponding to',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print('max r2 score corrasponding to ',final_r_state,'is',max_r_score)
    return final_r_state

# %%
lg=LinearRegression()
r_state=maxr2_score(lg,x,y)
print('Mean r2 score for linear Regression:',cross_val_score(lg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for linear Regression',cross_val_score(lg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  82 is 0.5690048183286156
# Mean r2 score for linear Regression: 0.20474097104942982
# stander deviation in r2 score for linear Regression 0.2167888077587062

# %%
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 21}

# %%
knr=KNeighborsRegressor(n_neighbors=21)
r_state=maxr2_score(knr,x,y)
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('stander deviation r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  82 is 0.7503847466949656
# Mean r2 score for KNN Regression: 0.2196608194779924
# stander deviation r2 score for KNN Regression: 0.2494596862773761

# %%
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
#let check max r2 score when we use lasso
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
print('Mean r2 score for Lasso Regration',cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for Lasso Regretion',cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  82 is 0.5681643824965871
# Mean r2 score for Lasso Regration 0.2036979959281985
# stander deviation in r2 score for Lasso Regretion 0.2183680972692878

# %%
ada_reg =AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 1000}

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=1,n_estimators=1000)
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for ada Boosting Regration: 0.24538719417532504
# Mean r2 score for ada Boosting Regration: 0.32523102714822344

# %%
r_state=maxr2_score(knr,x,y)
# Out:
# max r2 score corrasponding to  82 is 0.7503847466949656

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=82,test_size=0.30)
knr.fit(x_train,y_train)
y_pred=knr.predict(x_test)
print('RMSE is: ',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score is:',r2_score(y_test,y_pred))
print(y_pred)
print(y_test)
# Out:
# RMSE is:  0.20098597369340593
# r2_score is: 0.7288655763918457
# [1.54095238 1.34952381 1.45238095 ... 1.47714286 0.82333333 1.57047619]
# 14359    1.44
# 7577     0.92
# 13165    1.40
# 17229    1.36
# 5870     1.55
#          ...
# 14558    1.30
# 11370    1.25
# 16062    1.19
# 7567     0.89
# 11795    1.66
# Name: AveragePrice, Length: 5296, dtype: float64

# %%
joblib.dump(knr,'avocado_knr.obj')
# Out:
# ['avocado_knr.obj']

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Depending upon the different features that were used as the inputs to the machine learning to predict the average price of Hass Avacado.  We have used the EDA process to find out the correlated columns and data processing. And later we have used the different algorithms like linear regression, KNeighborsRegressor, LASSO & AdaBoostRegressor. Further, we have used the GridSearchCV parameter to get the best result for the algorithm.

# %% [markdown]
# After using all the above approaches we have concluded that KNeighborsRegressor provides the highest level of accuracy for machine learning i.e., approx... 75% regarding the average price of Hass Avacado.
